# %% [markdown]
# <a href="https://colab.research.google.com/github/Maria346-gif/python-course/blob/main/pandas_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
student_data = [["Alice", 20, "A" ,85],
                ["Bob", 22, "B", 78],
                ["Charlie" ,19 ,"A" ,92],
                ["David", 21, "C", 65],
                ["Eva" ,20 ,"B" ,74]
]
df=pd.DataFrame(student_data,columns=["Name","Age","Grade","Marks"])
df
# Out:
#       Name  Age Grade  Marks
# 0    Alice   20     A     85
# 1      Bob   22     B     78
# 2  Charlie   19     A     92
# 3    David   21     C     65
# 4      Eva   20     B     74

# %%
df.head(3)
# Out:
#       Name  Age Grade  Marks
# 0    Alice   20     A     85
# 1      Bob   22     B     78
# 2  Charlie   19     A     92

# %%
df[['Name','Age']]
# Out:
#       Name  Age
# 0    Alice   20
# 1      Bob   22
# 2  Charlie   19
# 3    David   21
# 4      Eva   20

# %%
df.loc[df['Grade'] == 'A']
# Out:
#       Name  Age Grade  Marks
# 0    Alice   20     A     85
# 2  Charlie   19     A     92
